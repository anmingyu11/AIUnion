# %% [markdown]
# ## 特征脸

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people()

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.target_names
# Out:
# array(['AJ Cook', 'AJ Lamas', 'Aaron Eckhart', ..., 'Zumrati Juma',
#        'Zurab Tsereteli', 'Zydrunas Ilgauskas'], dtype='<U35')

# %%
faces.images.shape
# Out:
# (13233, 62, 47)

# %%
faces.target_names.shape
# Out:
# (5749,)

# %%
random_indexes = np.random.permutation(len(faces.data))
X = faces.data[random_indexes]
example_faces = X[:36,:]
example_faces.shape
# Out:
# (36, 2914)

# %%
def plot_faces(faces):
    
    fig, axes = plt.subplots(6, 6, figsize=(10, 10),
                         subplot_kw={'xticks':[], 'yticks':[]},
    gridspec_kw=dict(hspace=0.1, wspace=0.1)) 
    for i, ax in enumerate(axes.flat):
        ax.imshow(faces[i].reshape(62, 47), cmap='bone')
    plt.show()
    

plot_faces(example_faces)

# %%
targetname = faces.target_names[random_indexes]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-d704b46f5a3d> in <module>
# ----> 1 targetname = faces.target_names[random_indexes]
#
# IndexError: index 7319 is out of bounds for axis 1 with size 5749

# %% [markdown]
# ## 特征脸

# %%
# %%time
from sklearn.decomposition import PCA 
pca = PCA(svd_solver='randomized')
pca.fit(X)
# Out:
# CPU times: user 1min 14s, sys: 1.46 s, total: 1min 16s
# Wall time: 20.5 s

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plot_faces(pca.components_)

# %% [markdown]
# ## 更多关于lfw_people数据集

# %%
faces2 = fetch_lfw_people(min_faces_per_person=60)
