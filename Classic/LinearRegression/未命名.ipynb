# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
import numpy as np

# %%
X = iris.data
y = iris.target

# %%
mean_ = [np.mean(X[:,i]) for i in range(X.shape[1])]

# %%
resX =  np.empty(shape=X.shape,dtype=float)

# %%
resX
# Out:
# array([[9.88131292e-324, 6.90908594e-310, 4.94065646e-324,
#         1.38338381e-322],
#        [6.90912408e-310,             nan, 6.90900610e-310,
#         1.69759663e-313],
#        [1.23516411e-322, 4.67672659e-310, 6.90912624e-310,
#         4.67666652e-310],
#        [1.69759663e-313, 0.00000000e+000, 0.00000000e+000,
#         9.88131292e-324],
#        [4.67672659e-310, 4.67672659e-310, 1.38338381e-322,
#         6.90912624e-310],
#        [4.67666652e-310, 9.88131292e-324, 4.88059032e-313,
#                     nan],
#        [4.67672659e-310, 6.90912629e-310, 4.94065646e-324,
#         4.88059032e-313],
#        [6.90912629e-310, 4.67672659e-310, 6.90900610e-310,
#         6.90912627e-310],
#        [4.88059032e-313, 6.90912629e-310, 7.85138443e-313,
#         6.90912427e-310],
#        [4.67672659e-310, 6.90900610e-310, 4.67672659e-310,
#         4.67672659e-310],
#        [4.67672659e-310, 1.69759663e-313, 2.96439388e-323,
#         4.67672659e-310],
# ...
